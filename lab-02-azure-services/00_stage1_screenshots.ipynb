# %% [markdown]
# #Stage 1 — Create the services yourself

# %% [markdown]
# ### 1. Storage Account (ADLS Gen2)

# %% [markdown]
# ![adls2_strg_lab2.png](./adls2_strg_lab2.png "adls2_strg_lab2.png")

# %% [markdown]
# ![adls2_strg_lab2_2.png](./adls2_strg_lab2_2.png "adls2_strg_lab2_2.png")

# %% [markdown]
# Enabled hierarchical namespace and set Azure Data Lake Storage as the primary service

# %% [markdown]
# ### 2. Key Vault

# %% [markdown]
# ![kv_screen_lab2.png](./kv_screen_lab2.png "kv_screen_lab2.png")

# %% [markdown]
# ### 3. Databricks workspace

# %% [markdown]
# ![dbws_screen_lab2.png](./dbws_screen_lab2.png "dbws_screen_lab2.png")

# %% [markdown]
# #### Naming conventions
# - Used standard prefixes: "dls" for Storage Account (ADLS Gen 2), "kv" for Key Vault, "db" for Databricks Workspace
# #### How the resources relate
# - Placed all three resources in the same Resource Group (UA_5816_BigData) and the same Region (East US) for normal network performance
